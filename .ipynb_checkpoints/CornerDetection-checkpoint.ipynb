# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def detectCorners(img):
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Convert Gray Scale Image to Float Values
    gray = np.float32(image)
    
    # Corner Harris Detection
    res = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)

    # result is dilated for marking the corners
    # this is just so we can plot out the points on the image shown
    res = cv2.dilate(res,None)

    # Threshold for an optimal value, it may vary depending on the image.
    image[res>0.01*res.max()]=[255,0,0]
    
    plt.imshow(image)

# %%
img = cv2.imread('./data/brickWall.jpg')
plt.imshow(img)
plt.imshow(img)
detectCorners(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-43d18432e6e1> in <module>
#       2 plt.imshow(img)
#       3 plt.imshow(img)
# ----> 4 detectCorners(img)
#
# <ipython-input-9-10b55cd66875> in detectCorners(img)
#       6
#       7     # Corner Harris Detection
# ----> 8     res = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)
#       9
#      10     # result is dilated for marking the corners
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\corner.cpp:269: error: (-215:Assertion failed) src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) || src.type() == (((5) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function 'cv::cornerEigenValsVecs'
